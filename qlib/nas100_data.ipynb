# %%
import qlib
# region in [REG_CN, REG_US]
from qlib.constant import REG_CN, REG_US
from qlib.data import D

provider_uri = "~/.qlib/qlib_data/us_data"  # target_dir
qlib.init(provider_uri=provider_uri, region=REG_US)
# Out:
# [16435:MainThread](2025-01-24 18:00:59,253) INFO - qlib.Initialization - [config.py:420] - default_conf: client.
# [16435:MainThread](2025-01-24 18:00:59,255) INFO - qlib.Initialization - [__init__.py:74] - qlib successfully initialized based on client settings.
# [16435:MainThread](2025-01-24 18:00:59,256) INFO - qlib.Initialization - [__init__.py:76] - data_path={'__DEFAULT_FREQ': PosixPath('/Users/diantu/.qlib/qlib_data/us_data')}

# %%
# 加载交易日历
calendar = D.calendar(start_time='2010-01-01', end_time='2017-12-31', freq='day')
print(calendar[:2])  # 打印前两个日期
# Out:
# [Timestamp('2010-01-04 00:00:00') Timestamp('2010-01-05 00:00:00')]

# %%
# 获取纳斯达克 100 成分股
instruments = D.instruments(market='nasdaq100')
print(D.list_instruments(instruments=instruments, start_time='2010-01-01', end_time='2017-12-31', as_list=True)[:6])
# Out:
# ['ATVI', 'ADBE', 'ALXN', 'ALGN', 'GOOGL', 'GOOG']

# %%
# fields = ['$close', '$volume', 'Ref($close, 1)', 'Mean($close, 3)', '$high-$low']  # 特征字段
# data = D.features(instruments, fields, start_time='2010-01-01', end_time='2017-12-31', freq='day')
# print(data.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:1186, in BaseProvider.features(self, instruments, fields, start_time, end_time, freq, disk_cache, inst_processors)
#    1185 try:
# -> 1186     return DatasetD.dataset(
#    1187         instruments, fields, start_time, end_time, freq, disk_cache, inst_processors=inst_processors
#    1188     )
#    1189 except TypeError:
#
# TypeError: LocalDatasetProvider.dataset() got multiple values for argument 'inst_processors'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 6
#       4 instruments = ['SH600000']  # 股票代码
#       5 fields = ['$close', '$volume', 'Ref($close, 1)', 'Mean($close, 3)', '$high-$low']  # 特征字段
# ----> 6 data = D.features(instruments, fields, start_time='2010-01-01', end_time='2017-12-31', freq='day')
#       7 print(data.head())
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:1190, in BaseProvider.features(self, instruments, fields, start_time, end_time, freq, disk_cache, inst_processors)
#    1186     return DatasetD.dataset(
#    1187         instruments, fields, start_time, end_time, freq, disk_cache, inst_processors=inst_processors
#    1188     )
#    1189 except TypeError:
# -> 1190     return DatasetD.dataset(instruments, fields, start_time, end_time, freq, inst_processors=inst_processors)
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:916, in LocalDatasetProvider.dataset(self, instruments, fields, start_time, end_time, freq, inst_processors)
#     912 column_names = self.get_column_names(fields)
#     913 if self.align_time:
#     914     # NOTE: if the frequency is a fixed value.
#     915     # align the data to fixed calendar point
# --> 916     cal = Cal.calendar(start_time, end_time, freq)
#     917     if len(cal) == 0:
#     918         return pd.DataFrame(
#     919             index=pd.MultiIndex.from_arrays([[], []], names=("instrument", "datetime")), columns=column_names
#     920         )
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:90, in CalendarProvider.calendar(self, start_time, end_time, freq, future)
#      71 def calendar(self, start_time=None, end_time=None, freq="day", future=False):
#      72     """Get calendar of certain market in given time range.
#      73
#      74     Parameters
#    (...)
#      88         calendar list
#      89     """
# ---> 90     _calendar, _calendar_index = self._get_calendar(freq, future)
#      91     if start_time == "None":
#      92         start_time = None
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:173, in CalendarProvider._get_calendar(self, freq, future)
#     171 flag = f"{freq}_future_{future}"
#     172 if flag not in H["c"]:
# --> 173     _calendar = np.array(self.load_calendar(freq, future))
#     174     _calendar_index = {x: i for i, x in enumerate(_calendar)}  # for fast search
#     175     H["c"][flag] = _calendar, _calendar_index
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/data.py:662, in LocalCalendarProvider.load_calendar(self, freq, future)
#     649 """Load original calendar timestamp from file.
#     650
#     651 Parameters
#    (...)
#     659     list of timestamps
#     660 """
#     661 try:
# --> 662     backend_obj = self.backend_obj(freq=freq, future=future).data
#     663 except ValueError:
#     664     if future:
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/storage/file_storage.py:132, in FileCalendarStorage.data(self)
#     130 @property
#     131 def data(self) -> List[CalVT]:
# --> 132     self.check()
#     133     # If cache is enabled, then return cache directly
#     134     if self.enable_read_cache:
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/storage/file_storage.py:72, in FileStorageMixin.check(self)
#      65 def check(self):
#      66     """check self.uri
#      67
#      68     Raises
#      69     -------
#      70     ValueError
#      71     """
# ---> 72     if not self.uri.exists():
#      73         raise ValueError(f"{self.storage_name} not exists: {self.uri}")
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/storage/file_storage.py:128, in FileCalendarStorage.uri(self)
#     126 @property
#     127 def uri(self) -> Path:
# --> 128     return self.dpm.get_data_uri(self._freq_file).joinpath(f"{self.storage_name}s", self.file_name)
#
# File /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/storage/file_storage.py:101, in FileCalendarStorage._freq_file(self)
#      99         freq = Freq.get_recent_freq(freq, self.support_freq)
#     100         if freq is None:
# --> 101             raise ValueError(f"can't find a freq from {self.support_freq} that can resample to {self.freq}!")
#     102     self._freq_file_cache = freq
#     103 return self._freq_file_cache
#
# ValueError: can't find a freq from [] that can resample to day!

# %%
# 计算Alpha158特征（因子）和标签（收益）
from qlib.contrib.data.handler import Alpha158

# 设置日期、股票池等参数
data_handler_config = {
    "start_time": "2019-12-02", # 开始时间
    "end_time": "2024-12-31",   # 结束时间
    "fit_start_time": "2019-12-02", # 训练集开始时间
    "fit_end_time": "2020-06-30",   # 训练集结束时间
    "instruments": instruments,  # 请确保 instruments 已定义
}

# 初始化 Alpha158 数据处理器
h158 = Alpha158(**data_handler_config)

# 获取列名（因子名称）
print(h158.get_cols())
# Out:
# [14345:MainThread](2025-01-24 17:03:32,416) INFO - qlib.timer - [log.py:127] - Time cost: 13.942s | Loading data Done
# [14345:MainThread](2025-01-24 17:03:32,439) INFO - qlib.timer - [log.py:127] - Time cost: 0.008s | DropnaLabel Done
# [14345:MainThread](2025-01-24 17:03:32,484) INFO - qlib.timer - [log.py:127] - Time cost: 0.044s | CSZScoreNorm Done
# [14345:MainThread](2025-01-24 17:03:32,485) INFO - qlib.timer - [log.py:127] - Time cost: 0.068s | fit & process data Done
# [14345:MainThread](2025-01-24 17:03:32,485) INFO - qlib.timer - [log.py:127] - Time cost: 14.012s | Init data Done
# ['KMID', 'KLEN', 'KMID2', 'KUP', 'KUP2', 'KLOW', 'KLOW2', 'KSFT', 'KSFT2', 'OPEN0', 'HIGH0', 'LOW0', 'VWAP0', 'ROC5', 'ROC10', 'ROC20', 'ROC30', 'ROC60', 'MA5', 'MA10', 'MA20', 'MA30', 'MA60', 'STD5', 'STD10', 'STD20', 'STD30', 'STD60', 'BETA5', 'BETA10', 'BETA20', 'BETA30', 'BETA60', 'RSQR5', 'RSQR10', 'RSQR20', 'RSQR30', 'RSQR60', 'RESI5', 'RESI10', 'RESI20', 'RESI30', 'RESI60', 'MAX5', 'MAX10', 'MAX20', 'MAX30', 'MAX60', 'MIN5', 'MIN10', 'MIN20', 'MIN30', 'MIN60', 'QTLU5', 'QTLU10', 'QTLU20', 'QTLU30', 'QTLU60', 'QTLD5', 'QTLD10', 'QTLD20', 'QTLD30', 'QTLD60', 'RANK5', 'RANK10', 'RANK20', 'RANK30', 'RANK60', 'RSV5', 'RSV10', 'RSV20', 'RSV30', 'RSV60', 'IMAX5', 'IMAX10', 'IMAX20', 'IMAX30', 'IMAX60', 'IMIN5', 'IMIN10', 'IMIN20', 'IMIN30', 'IMIN60', 'IMXD5', 'IMXD10', 'IMXD20', 'IMXD30', 'IMXD60', 'CORR5', 'CORR10', 'CORR20', 'CORR30', 'CORR60', 'CORD5', 'CORD10', 'CORD20', 'CORD30', 'CORD60', 'CNTP5', 'CNTP10', 'CNTP20', 'CNTP30', 'CNTP60', 'CNTN5', 'CNTN10', 'CNTN20', 'CNTN30', 'CNTN60', 'CNTD5', 'CNTD10', 'CNTD20', 'CNTD30', 'CNTD60', 'SUMP5', 'SUMP10', 'SUMP20', 'SUMP30', 'SUMP60', 'SUMN5', 'SUMN10', 'SUMN20', 'SUMN30', 'SUMN60', 'SUMD5', 'SUMD10', 'SUMD20', 'SUMD30', 'SUMD60', 'VMA5', 'VMA10', 'VMA20', 'VMA30', 'VMA60', 'VSTD5', 'VSTD10', 'VSTD20', 'VSTD30', 'VSTD60', 'WVMA5', 'WVMA10', 'WVMA20', 'WVMA30', 'WVMA60', 'VSUMP5', 'VSUMP10', 'VSUMP20', 'VSUMP30', 'VSUMP60', 'VSUMN5', 'VSUMN10', 'VSUMN20', 'VSUMN30', 'VSUMN60', 'VSUMD5', 'VSUMD10', 'VSUMD20', 'VSUMD30', 'VSUMD60', 'LABEL0']

# %%
print(len(h158.get_cols()))
# Out:
# 159

# %%
Alpha158_sci300_feats = h158.fetch(col_set='feature')
Alpha158_sci300_feats
# Out:
#                            KMID      KLEN     KMID2       KUP      KUP2  \
# datetime   instrument
# 2020-01-02 SH600000    0.000000  0.015237  0.000000  0.013633  0.894736
#            SH600004   -0.002278  0.012529 -0.181813  0.003417  0.272729
#            SH600009   -0.018399  0.022967 -0.801102  0.001269  0.055252
#            SH600010    0.000000  0.015038  0.000000  0.007519  0.500000
#            SH600011    0.005348  0.016043  0.333329  0.008913  0.555557
# ...                         ...       ...       ...       ...       ...
# 2020-09-25 SZ300413    0.014902  0.028392  0.524862  0.010510  0.370167
#            SZ300433   -0.015789  0.031579 -0.499997  0.000929  0.029414
#            SZ300498   -0.012243  0.019589 -0.625002  0.004897  0.249999
#            SZ300601   -0.021212  0.063011 -0.336641  0.028770  0.456576
#            SZ300628   -0.005217  0.024066 -0.216781  0.003534  0.146856
#
#                            KLOW     KLOW2      KSFT     KSFT2     OPEN0  ...  \
# datetime   instrument                                                    ...
# 2020-01-02 SH600000    0.001604  0.105264 -0.012029 -0.789472  1.000000  ...
#            SH600004    0.006834  0.545458  0.001139  0.090916  1.002283  ...
#            SH600009    0.003299  0.143646 -0.016369 -0.712708  1.018744  ...
#            SH600010    0.007519  0.500000  0.000000  0.000000  1.000000  ...
#            SH600011    0.001783  0.111114 -0.001783 -0.111114  0.994681  ...
# ...                         ...       ...       ...       ...       ...  ...
# 2020-09-25 SZ300413    0.002980  0.104971  0.007372  0.259665  0.985317  ...
#            SZ300433    0.014861  0.470589 -0.001858 -0.058823  1.016043  ...
#            SZ300498    0.002449  0.124999 -0.014691 -0.750001  1.012395  ...
#            SZ300601    0.013030  0.206783 -0.036952 -0.586434  1.021672  ...
#            SZ300628    0.015315  0.636362  0.006563  0.272725  1.005244  ...
#
#                          VSUMN5   VSUMN10   VSUMN20   VSUMN30   VSUMN60  \
# datetime   instrument
# 2020-01-02 SH600000    0.162038  0.422264  0.444087  0.480478  0.494527
#            SH600004    0.000000  0.365170  0.463112  0.498544  0.491698
#            SH600009    0.033771  0.260016  0.380061  0.423817  0.488847
#            SH600010    0.409818  0.573568  0.485123  0.483287  0.481808
#            SH600011    0.064878  0.299046  0.409218  0.409027  0.449194
# ...                         ...       ...       ...       ...       ...
# 2020-09-25 SZ300413    0.428346  0.676687  0.642549  0.515998  0.517741
#            SZ300433    0.750042  0.778911  0.578567  0.512691  0.532542
#            SZ300498    0.651959  0.550290  0.741564  0.507788  0.520992
#            SZ300601    0.465855  0.508975  0.514560  0.523693  0.500761
#            SZ300628    1.000000  0.553051  0.515830  0.521809  0.515315
#
#                          VSUMD5   VSUMD10   VSUMD20   VSUMD30   VSUMD60
# datetime   instrument
# 2020-01-02 SH600000    0.675923  0.155473  0.111826  0.039044  0.010946
#            SH600004    1.000000  0.269660  0.073775  0.002912  0.016604
#            SH600009    0.932458  0.479967  0.239879  0.152365  0.022306
#            SH600010    0.180364 -0.147136  0.029754  0.033425  0.036383
#            SH600011    0.870244  0.401908  0.181564  0.181946  0.101613
# ...                         ...       ...       ...       ...       ...
# 2020-09-25 SZ300413    0.143307 -0.353373 -0.285098 -0.031997 -0.035482
#            SZ300433   -0.500084 -0.557822 -0.157134 -0.025382 -0.065085
#            SZ300498   -0.303918 -0.100581 -0.483128 -0.015577 -0.041983
#            SZ300601    0.068290 -0.017950 -0.029119 -0.047386 -0.001522
#            SZ300628   -1.000000 -0.106102 -0.031660 -0.043617 -0.030631
#
# [54000 rows x 158 columns]

# %%
# 计算Alpha360特征（因子）和标签（收益）
from qlib.contrib.data.handler import Alpha360

# 设置日期、股票池等参数
data_handler_config = {
    "start_time": "2019-12-02",
    "end_time": "2024-12-31",
    "fit_start_time": "2019-12-02",
    "fit_end_time": "2024-12-31",
    "instruments": instruments,  # 请确保 instruments 已定义
}

# 初始化 Alpha360 数据处理器
h360 = Alpha360(**data_handler_config)

# 获取列名（因子名称）
print(h360.get_cols())
# Out:
# [16435:MainThread](2025-01-24 18:04:02,201) INFO - qlib.timer - [log.py:127] - Time cost: 12.273s | Loading data Done
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:59: FutureWarning: The 'axis' keyword in DataFrame.resample is deprecated and will be removed in a future version.
#   delayed(_naive_group_apply)(sub_df) for idx, sub_df in df.resample(resample_rule, axis=axis, level=level)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:59: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   delayed(_naive_group_apply)(sub_df) for idx, sub_df in df.resample(resample_rule, axis=axis, level=level)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/utils/paral.py:55: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   return df.groupby(axis=axis, level=level).apply(apply_func)
# [16435:MainThread](2025-01-24 18:04:08,301) INFO - qlib.timer - [log.py:127] - Time cost: 6.086s | ProcessInf Done
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/qlib/data/dataset/processor.py:246: RuntimeWarning: Mean of empty slice
#   self.mean_train = np.nanmean(df[cols].values, axis=0)
# /opt/anaconda3/envs/pytorch_python3/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# [16435:MainThread](2025-01-24 18:04:08,376) INFO - qlib.timer - [log.py:127] - Time cost: 0.074s | ZScoreNorm Done
# [16435:MainThread](2025-01-24 18:04:08,407) INFO - qlib.timer - [log.py:127] - Time cost: 0.031s | Fillna Done
# [16435:MainThread](2025-01-24 18:04:08,417) INFO - qlib.timer - [log.py:127] - Time cost: 0.005s | DropnaLabel Done
# [16435:MainThread](2025-01-24 18:04:08,476) INFO - qlib.timer - [log.py:127] - Time cost: 0.058s | CSZScoreNorm Done
# [16435:MainThread](2025-01-24 18:04:08,476) INFO - qlib.timer - [log.py:127] - Time cost: 6.275s | fit & process data Done
# [16435:MainThread](2025-01-24 18:04:08,477) INFO - qlib.timer - [log.py:127] - Time cost: 18.549s | Init data Done
# ['CLOSE59', 'CLOSE58', 'CLOSE57', 'CLOSE56', 'CLOSE55', 'CLOSE54', 'CLOSE53', 'CLOSE52', 'CLOSE51', 'CLOSE50', 'CLOSE49', 'CLOSE48', 'CLOSE47', 'CLOSE46', 'CLOSE45', 'CLOSE44', 'CLOSE43', 'CLOSE42', 'CLOSE41', 'CLOSE40', 'CLOSE39', 'CLOSE38', 'CLOSE37', 'CLOSE36', 'CLOSE35', 'CLOSE34', 'CLOSE33', 'CLOSE32', 'CLOSE31', 'CLOSE30', 'CLOSE29', 'CLOSE28', 'CLOSE27', 'CLOSE26', 'CLOSE25', 'CLOSE24', 'CLOSE23', 'CLOSE22', 'CLOSE21', 'CLOSE20', 'CLOSE19', 'CLOSE18', 'CLOSE17', 'CLOSE16', 'CLOSE15', 'CLOSE14', 'CLOSE13', 'CLOSE12', 'CLOSE11', 'CLOSE10', 'CLOSE9', 'CLOSE8', 'CLOSE7', 'CLOSE6', 'CLOSE5', 'CLOSE4', 'CLOSE3', 'CLOSE2', 'CLOSE1', 'CLOSE0', 'OPEN59', 'OPEN58', 'OPEN57', 'OPEN56', 'OPEN55', 'OPEN54', 'OPEN53', 'OPEN52', 'OPEN51', 'OPEN50', 'OPEN49', 'OPEN48', 'OPEN47', 'OPEN46', 'OPEN45', 'OPEN44', 'OPEN43', 'OPEN42', 'OPEN41', 'OPEN40', 'OPEN39', 'OPEN38', 'OPEN37', 'OPEN36', 'OPEN35', 'OPEN34', 'OPEN33', 'OPEN32', 'OPEN31', 'OPEN30', 'OPEN29', 'OPEN28', 'OPEN27', 'OPEN26', 'OPEN25', 'OPEN24', 'OPEN23', 'OPEN22', 'OPEN21', 'OPEN20', 'OPEN19', 'OPEN18', 'OPEN17', 'OPEN16', 'OPEN15', 'OPEN14', 'OPEN13', 'OPEN12', 'OPEN11', 'OPEN10', 'OPEN9', 'OPEN8', 'OPEN7', 'OPEN6', 'OPEN5', 'OPEN4', 'OPEN3', 'OPEN2', 'OPEN1', 'OPEN0', 'HIGH59', 'HIGH58', 'HIGH57', 'HIGH56', 'HIGH55', 'HIGH54', 'HIGH53', 'HIGH52', 'HIGH51', 'HIGH50', 'HIGH49', 'HIGH48', 'HIGH47', 'HIGH46', 'HIGH45', 'HIGH44', 'HIGH43', 'HIGH42', 'HIGH41', 'HIGH40', 'HIGH39', 'HIGH38', 'HIGH37', 'HIGH36', 'HIGH35', 'HIGH34', 'HIGH33', 'HIGH32', 'HIGH31', 'HIGH30', 'HIGH29', 'HIGH28', 'HIGH27', 'HIGH26', 'HIGH25', 'HIGH24', 'HIGH23', 'HIGH22', 'HIGH21', 'HIGH20', 'HIGH19', 'HIGH18', 'HIGH17', 'HIGH16', 'HIGH15', 'HIGH14', 'HIGH13', 'HIGH12', 'HIGH11', 'HIGH10', 'HIGH9', 'HIGH8', 'HIGH7', 'HIGH6', 'HIGH5', 'HIGH4', 'HIGH3', 'HIGH2', 'HIGH1', 'HIGH0', 'LOW59', 'LOW58', 'LOW57', 'LOW56', 'LOW55', 'LOW54', 'LOW53', 'LOW52', 'LOW51', 'LOW50', 'LOW49', 'LOW48', 'LOW47', 'LOW46', 'LOW45', 'LOW44', 'LOW43', 'LOW42', 'LOW41', 'LOW40', 'LOW39', 'LOW38', 'LOW37', 'LOW36', 'LOW35', 'LOW34', 'LOW33', 'LOW32', 'LOW31', 'LOW30', 'LOW29', 'LOW28', 'LOW27', 'LOW26', 'LOW25', 'LOW24', 'LOW23', 'LOW22', 'LOW21', 'LOW20', 'LOW19', 'LOW18', 'LOW17', 'LOW16', 'LOW15', 'LOW14', 'LOW13', 'LOW12', 'LOW11', 'LOW10', 'LOW9', 'LOW8', 'LOW7', 'LOW6', 'LOW5', 'LOW4', 'LOW3', 'LOW2', 'LOW1', 'LOW0', 'VWAP59', 'VWAP58', 'VWAP57', 'VWAP56', 'VWAP55', 'VWAP54', 'VWAP53', 'VWAP52', 'VWAP51', 'VWAP50', 'VWAP49', 'VWAP48', 'VWAP47', 'VWAP46', 'VWAP45', 'VWAP44', 'VWAP43', 'VWAP42', 'VWAP41', 'VWAP40', 'VWAP39', 'VWAP38', 'VWAP37', 'VWAP36', 'VWAP35', 'VWAP34', 'VWAP33', 'VWAP32', 'VWAP31', 'VWAP30', 'VWAP29', 'VWAP28', 'VWAP27', 'VWAP26', 'VWAP25', 'VWAP24', 'VWAP23', 'VWAP22', 'VWAP21', 'VWAP20', 'VWAP19', 'VWAP18', 'VWAP17', 'VWAP16', 'VWAP15', 'VWAP14', 'VWAP13', 'VWAP12', 'VWAP11', 'VWAP10', 'VWAP9', 'VWAP8', 'VWAP7', 'VWAP6', 'VWAP5', 'VWAP4', 'VWAP3', 'VWAP2', 'VWAP1', 'VWAP0', 'VOLUME59', 'VOLUME58', 'VOLUME57', 'VOLUME56', 'VOLUME55', 'VOLUME54', 'VOLUME53', 'VOLUME52', 'VOLUME51', 'VOLUME50', 'VOLUME49', 'VOLUME48', 'VOLUME47', 'VOLUME46', 'VOLUME45', 'VOLUME44', 'VOLUME43', 'VOLUME42', 'VOLUME41', 'VOLUME40', 'VOLUME39', 'VOLUME38', 'VOLUME37', 'VOLUME36', 'VOLUME35', 'VOLUME34', 'VOLUME33', 'VOLUME32', 'VOLUME31', 'VOLUME30', 'VOLUME29', 'VOLUME28', 'VOLUME27', 'VOLUME26', 'VOLUME25', 'VOLUME24', 'VOLUME23', 'VOLUME22', 'VOLUME21', 'VOLUME20', 'VOLUME19', 'VOLUME18', 'VOLUME17', 'VOLUME16', 'VOLUME15', 'VOLUME14', 'VOLUME13', 'VOLUME12', 'VOLUME11', 'VOLUME10', 'VOLUME9', 'VOLUME8', 'VOLUME7', 'VOLUME6', 'VOLUME5', 'VOLUME4', 'VOLUME3', 'VOLUME2', 'VOLUME1', 'VOLUME0', 'LABEL0']

# %%
Alpha360_nasdaq100_feats = h360.fetch(col_set='feature')
Alpha360_nasdaq100_feats
# Out:
#                                    CLOSE59   CLOSE58   CLOSE57   CLOSE56  \
# datetime   datetime   instrument
# 2019-12-02 2019-12-02 AAL         0.186861  0.293156  0.394278  0.422461
#                       AAPL       -0.714396 -0.678254 -0.567652 -0.582602
#                       ADBE       -0.202837 -0.254117 -0.234346 -0.235206
#                       ADI         0.208909  0.251567  0.292752  0.339141
#                       ADP         0.107860  0.006271 -0.082255 -0.084241
# ...                                    ...       ...       ...       ...
# 2020-11-10 2020-11-10 WBA        -0.024068 -0.081683 -0.143187 -0.174010
#                       WDAY       -0.323703 -0.336177 -0.275358 -0.315598
#                       XEL        -0.109055 -0.138367 -0.177246 -0.144579
#                       XLNX       -0.570009 -0.606556 -0.650490 -0.634336
#                       ZM         -1.037698 -1.085532 -0.888089 -0.908493
#
#                                    CLOSE55   CLOSE54   CLOSE53   CLOSE52  \
# datetime   datetime   instrument
# 2019-12-02 2019-12-02 AAL         0.423248  0.066156  0.206345  0.197918
#                       AAPL       -0.664204 -0.651904 -0.645797 -0.617348
#                       ADBE       -0.234832 -0.169952 -0.147655 -0.228776
#                       ADI         0.350580  0.297451  0.296741  0.349385
#                       ADP        -0.106185 -0.153086 -0.139483 -0.173206
# ...                                    ...       ...       ...       ...
# 2020-11-10 2020-11-10 WBA        -0.148006 -0.178385 -0.274044 -0.205431
#                       WDAY       -0.343150 -0.296356  0.123034  0.186398
#                       XEL        -0.099309 -0.192695 -0.250049 -0.223704
#                       XLNX       -0.623722 -0.596627 -0.544086 -0.599357
#                       ZM         -1.007076 -0.917050 -0.867132 -0.884159
#
#                                    CLOSE51   CLOSE50  ...   VOLUME9   VOLUME8  \
# datetime   datetime   instrument                      ...
# 2019-12-02 2019-12-02 AAL         0.145760  0.091171  ... -0.033686 -0.029471
#                       AAPL       -0.657844 -0.724590  ... -0.023536 -0.034971
#                       ADBE       -0.210127 -0.267894  ... -0.050283 -0.040504
#                       ADI         0.319772  0.295374  ... -0.011577 -0.010529
#                       ADP        -0.133943 -0.139960  ... -0.011474 -0.022125
# ...                                    ...       ...  ...       ...       ...
# 2020-11-10 2020-11-10 WBA        -0.275064 -0.363784  ... -0.062622 -0.060356
#                       WDAY        0.784334  0.694612  ... -0.036721 -0.007846
#                       XEL        -0.227703 -0.180595  ... -0.007200  0.012339
#                       XLNX       -0.561897 -0.598979  ...  0.070066  0.029192
#                       ZM         -0.837055 -0.521196  ... -0.060903 -0.065795
#
#                                    VOLUME7   VOLUME6   VOLUME5   VOLUME4  \
# datetime   datetime   instrument
# 2019-12-02 2019-12-02 AAL         0.011311 -0.025558 -0.034644 -0.030219
#                       AAPL       -0.007308  0.005082 -0.035525 -0.021613
#                       ADBE       -0.035150 -0.050897 -0.046808 -0.029712
#                       ADI         0.027923  0.036388 -0.012350  0.034544
#                       ADP        -0.016733 -0.025797 -0.018077 -0.018434
# ...                                    ...       ...       ...       ...
# 2020-11-10 2020-11-10 WBA        -0.038413 -0.062124 -0.052703 -0.048309
#                       WDAY        0.000676 -0.024717 -0.034763  0.036516
#                       XEL        -0.013701 -0.006751 -0.011968 -0.016711
#                       XLNX        0.007878 -0.015503 -0.013037  0.032491
#                       ZM         -0.047583 -0.063872 -0.060706 -0.053718
#
#                                    VOLUME3   VOLUME2   VOLUME1  VOLUME0
# datetime   datetime   instrument
# 2019-12-02 2019-12-02 AAL        -0.022460 -0.010322 -0.018204      1.0
#                       AAPL       -0.006398 -0.009052 -0.017095      1.0
#                       ADBE       -0.019877 -0.010227 -0.018709      1.0
#                       ADI         0.202515  0.001342 -0.015036      1.0
#                       ADP         0.019116 -0.008248 -0.016481      1.0
# ...                                    ...       ...       ...      ...
# 2020-11-10 2020-11-10 WBA        -0.056826 -0.011240 -0.013855      1.0
#                       WDAY        0.005596 -0.008205 -0.003951      1.0
#                       XEL        -0.023449 -0.009538 -0.003951      1.0
#                       XLNX       -0.006452 -0.006834 -0.002673      1.0
#                       ZM         -0.058715 -0.012181 -0.010120      1.0
#
# [24617 rows x 360 columns]

# %%
# 保存为 CSV 文件
csv_file_path = "alpha360_nasdaq100_feats.csv"  # 保存路径
Alpha360_nasdaq100_feats.to_csv(csv_file_path, index=True)  # 保存索引

print(f"数据已保存到: {csv_file_path}")
# Out:
# 数据已保存到: alpha360_nasdaq100_data.csv
